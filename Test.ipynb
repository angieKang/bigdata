# %% [markdown]
# #Jupyter Tutorial

# %% [markdown]
# Project Jupyter exists to develop open-source software, open-standards, and services for interactive computing across dozens of programming languages.

# %% [markdown]
# ## Code

# %%
print('Hello Jupyter notebook')
# Out:
# Hello Jupyter notebook

# %%
10+11
# Out:
# 21

# %%
def add(a,b):
    return a +b

# %%
add(10,11)
# Out:
# 21

# %% [markdown]
# ## Markdown

# %% [markdown]
# \begin{align}
# \dot{x} &= \sigma(y-x) \\
# \dot{y} &= \rho x - y - xz \\
# \dot{z} &= -\beta z + xy
# \end{align}

# %% [markdown]
# \begin{equation*}
# P(E) = {n \choose k} p^k (1-p)^{ n-k}
# \end{equation*}

# %% [markdown]
# ## Image

# %% [markdown]
# ![Jupyter notebook](https://jupyter.org/assets/jupyterpreview.png)

# %%
from IPython.display import Image

# %%
Image(url="https://jupyter.org/assets/jupyterpreview.png", width=400,height=300)
# Out:
# <img src="https://jupyter.org/assets/jupyterpreview.png" width="400" height="300"/>

# %% [markdown]
# ## Video

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('9OzvUIlkN6U',width=320,height=240)
