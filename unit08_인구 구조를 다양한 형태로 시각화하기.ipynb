# %% [markdown]
# ## 지역명을 입력받아 그 지역의 인구구조를 시각화

# %%
import csv
import matplotlib.pyplot as plt

f = open('age.csv','r',encoding='cp949')
data = csv.reader(f)
result = []
#인구 구조가 궁금한 지역의 이름을 input()함수로 입력받음
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요 : ')

for row in data:
    #입력받은 내용이 포함된 값을 찾음
    if name in row[0]:     
        for i in row[3:]:      
            result.append(int(i.replace(',','')))       

plt.style.use('ggplot')     #격자 무늬 스타일 지정
plt.rc('font', family='Malgun Gothic')
plt.title(name+' 지역의 인구 구조')
plt.plot(result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요 : 철산3동

# %% [markdown]
# ## 막대그래프 그리기

# %%
import matplotlib.pyplot as plt
#bar(막대를 표시할 위치, 막대의 높이)
plt.bar([0,1,2,4,6,10],[1,2,3,5,6,7])
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('age.csv','r',encoding='cp949')
data = csv.reader(f)
result = []

for row in data:
    if '철산3동' in row[0]:          #row 0번이 철산3동을 포함하고 있다면
        for i in row[3:]:           #0번은 지역명, 1번과 2번은 해당 지역의 총 인구수 ->3번부터 인구수
            result.append(int(i))   #해당 연령의 인구수 리스트에 정수형으로 순서대로 저장하기    

#bar(막대를 표시할 위치(range(101):0~101번까지), 막대의 높이)
#plt.bar(range(101), result)
#수평 방향의 막대그래프
plt.barh(range(101), result)
plt.show()

# %% [markdown]
# ## 항아리 모양 그래프 그리기(성별정보 포함)

# %%
import csv 
import matplotlib.pyplot as plt

f = open('gender.csv')
data = csv.reader(f)
m = []
f = []

for row in data:
    if '신도림' in row[0]:
        for i in range(0,101):
            #남성 인덱스는 3부터 시작 0:지역명/1:총인구1/2:총인구2
            m.append(-int(row[i+3]))  #남자는 음수로 표현되도록 지정
            #for i in row[3:104]:
            #    m.append(-int(i))
            
            #여성 인덱스는 -1부터 시작 뒤(100세 이상)에서부터 -101(0세)까지
            f.append(int(row[-(i+1)]))
            #for i in row[106:]:
            #    f.append(int(i))
            
#reverse() :리스트의 값을 역순으로 재배열
f.reverse()     

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False    #-기호 한글폰트 깨짐방지
plt.title('신도림 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()

# %% [markdown]
# ## 우리 동네 인구 구조를 항아리 모양 그래프로 그리기

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv')
data = csv.reader(f)

m = []
f = []

name = input('찾고 싶은 지역의 이름을 알려주세요 : ')

for row in data :
    if name in row[0]:
        for i in row[3:104]:
            m.append(-int(i))
        for i in row[106:]:
            f.append(int(i))
            
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False  
plt.title(name+' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 철산3동
