# %% [markdown]
# ## 꺾은선 그래프로 표현하기

# %%
import csv
f=open('gender.csv')
data = csv.reader(f)
m = []
f = []

name = input('궁금한 동네를 입력해주세요:')
for row in data:
    if name in row[0]:
        for i in range(3,104):
            m.append(int(row[i]))
            f.append(int(row[i+103]))
        break
        
import matplotlib.pyplot as plt
plt.plot(m, label='Male')
plt.plot(f, label='Female')
plt.legend()
plt.show()
# Out:
# 궁금한 동네를 입력해주세요:철산3동

# %% [markdown]
# ## 막대그래프로 표현하기

# %%
import csv
f=open('gender.csv')
data = csv.reader(f)
result = []

name = input('궁금한 동네를 입력해주세요:')
for row in data:
    if name in row[0]:
        for i in range(3,104):
            result.append(int(row[i])-int(row[i+103]))
            #여성이 많으면 -값, 남성이 많으면 +값으로 표시
        break
        
import matplotlib.pyplot as plt
plt.bar(range(101), result)
plt.show()
# Out:
# 궁금한 동네를 입력해주세요:철산3동

# %% [markdown]
# ## 산점도로 표현하기

# %% [markdown]
# ## scatter()함수로 표현하기

# %%
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,30,20,40])
plt.show()

# %% [markdown]
# ## 버블 차트로 표현하기

# %%
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,30,20,40], s=[100,200,300,400])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,30,20,40], s=[100,200,300,400], c=['red','blue','green','gold'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,30,20,40], s=[100,200,300,400],c=range(4))
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,30,20,40], s=[100,200,300,400],c=range(4), cmap='jet')
#cmap: 컬러바에 사용될 색상 종류 설정가능. jet는 무지개무늬
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import random
x = []
y = []
size = []
for i in range(100):
    #randint(a,b)  a와 b사이의 random값(a<= random <=b) 출력
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))
plt.scatter(x, y, s=size ,c=size, cmap='jet', alpha=0.7)
#c=size로 하면 크기에 따라 다른 색 표현 가능.
#alpha로 투명도 조절. 0은 투명, 1은 불투명
plt.colorbar()
plt.show()

# %% [markdown]
# ## 제주도의 연령대별 성별 비율을 산점도로 표현하기

# %%
import csv
f=open('gender.csv')
data = csv.reader(f)
m = []
f = []

name = input('궁금한 동네를 입력해주세요:')
for row in data:
    if name in row[0]:
        for i in range(3,104):
            m.append(int(row[i]))
            f.append(int(row[i+103]))
        break
        
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(10,5), dpi=300)
plt.title(name+' 지역의 성별 인구 그래프')
plt.scatter(m, f, c=range(101), alpha=0.7, cmap='jet')
plt.colorbar()
plt.plot(range(max(m)),range(max(m)),'g')    #추세선 추가
plt.xlabel('남성 인구수')
plt.ylabel('여성 인구수')
plt.show()
# Out:
# 궁금한 동네를 입력해주세요:철산3동
